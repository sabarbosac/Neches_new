# %% [markdown]
# # Download Daymet

# %% [markdown]
# Daymet provides gridded meteorological data for North American at 1km spatial resolution with daily timestep from 1980 ~ present. [website](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1328) and [user guide](https://daac.ornl.gov/DAYMET/guides/Daymet_V3_CFMosaics.html)
#
# Available variables:
#
# | Variable | Description (units) |
# | ---- | ---- |
# | tmax | Daily maximum 2-meter air temperature (°C) |
# | tmin | Daily minimum 2-meter air temperature (°C) |
# | prcp | Daily total precipitation (mm/day) |
# | srad | Incident shortwave radiation flux density (W/m2) |
# | vp   | Water vapor pressure (Pa) |
# | swe  | Snow water equivalent (kg/m2) |
# | dayl | Duration of the daylight period (seconds/day) |
#
# Notes:
#  - The Daymet calendar is based on a standard calendar year. All Daymet years, including leap years, have 1 - 365 days. For leap years, the Daymet database includes leap day (February 29) and values for December 31 are discarded from leap years to maintain a 365-day year.

# %%
# Use branch v1.3. use env watershed_workflow_daymet
# use the watershed_workflowrc to set the chrdir to the data directory

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
import watershed_workflow
import watershed_workflow.ui
import logging
watershed_workflow.ui.setup_logging(1,None)

import numpy as np
import rasterio
import fiona
import watershed_workflow.daymet

import os,sys
import numpy as np
import pandas
from matplotlib import pyplot as plt
from matplotlib import cm as pcm
import logging
import pandas as pd
import geopandas as gpd
# import seaborn as sns
import shapely
import copy
import scipy
import datetime
import netCDF4 as nc

import watershed_workflow 
import watershed_workflow.source_list
import watershed_workflow.ui
import watershed_workflow.utils
import watershed_workflow.plot
import watershed_workflow.mesh
import watershed_workflow.condition
# import watershed_workflow.densify_rivers_hucs
# import watershed_workflow.create_river_mesh
watershed_workflow.ui.setup_logging(1,None)

# import pygeoutils as geoutils
# from pynhd import NLDI
import ipympl

# %%
sources = watershed_workflow.source_list.get_default_sources()
name = 'Neches' # name the domain, used in filenames, etc
hucs = ['1202'] # a list of HUCs to run
huc_level = None # if provided, an int setting the level at which to include HUC boundaries
crs = watershed_workflow.crs.daymet_crs()

# %%
# Get shapefile for the domain of analysis. Use the USGS gauge ID to pull data
sources = watershed_workflow.source_list.get_default_sources()
my_hucs = []
for huc in hucs:
    _, ws = watershed_workflow.get_hucs(sources['HUC'], huc, huc_level, crs)
    my_hucs.extend(ws)

# Option 1: Get the basin gauge boundary directly from the shp
# Note: if pynhd has an "verification certificates" error, change ssl to False for the ar.retrieve_text
# and ar.retrieve_json in the nwis.py file 
# Users/gpq/opt/anaconda/envs/Env_test/lib/python3.11/site-packages/pygeohydro/nwis.py , line 146, 537

# Most general option, still a hack, is to change the async_retriever.py function line 337 to : ssl: SSLContext | bool | None = False,
# Add verify=False to the requests.get to all the .py files in watershed_workflow/sources/*.py
# Out:
# 2023-05-03 13:36:53,055 - root - INFO:
# 2023-05-03 13:36:53,057 - root - INFO: Loading level 4 HUCs in 1202
# 2023-05-03 13:36:53,058 - root - INFO: ------------------------------
# 2023-05-03 13:36:53,060 - root - INFO: Using HUC file "/Users/gpq/ORNL/Projects/ATS_runs/global_data/hydrography/NHDPlus_H_1202_GDB/NHDPlus_H_1202.gdb"
# 2023-05-03 13:36:53,123 - root - INFO: ... found 1 HUCs
# 2023-05-03 13:36:53,124 - root - INFO:   -- 1202
# 2023-05-03 13:36:53,125 - root - INFO: Converting to out_crs
# 2023-05-03 13:36:53,140 - root - INFO: Converting to shapely

# %%
# gauge_ID='08041780' # National Water Service streamflow gauge ID (USGS ID)
# watershed_gauge = NLDI().get_basins([gauge_ID])
# watershed_gauge.to_file(f'../data-processed/basin/watershed_gaugeID_{gauge_ID}.shp')
# path_shp_basin = 'data/basin/watershed_gauge' # Path to save shp
HUC4 = '1202' # HUC4 ID
gpd_watershed = gpd.read_file(f'../data-processed/basin/watershed_HUC4_{HUC4}.shp')
_, watershed_gauge=watershed_workflow.get_shapes(f'../data-processed/basin/watershed_HUC4_{HUC4}.shp',in_crs = gpd_watershed.crs,out_crs = watershed_workflow.crs.daymet_crs())

watershed_area = watershed_gauge[0].area/1e6 # Area in [km2]
# my_hucs = watershed_gauge[0]
my_hucs = [my_hucs[0].intersection(watershed_gauge[0])]
print('Drainage area = ', watershed_area, 'km^2')

# Get watershed in the right format
watershed = watershed_workflow.split_hucs.SplitHUCs(my_hucs)
# Out:
# 2023-05-03 13:36:59,083 - root - INFO:
# 2023-05-03 13:36:59,084 - root - INFO: Loading shapes
# 2023-05-03 13:36:59,084 - root - INFO: ------------------------------
# 2023-05-03 13:36:59,085 - root - INFO: Loading file: '../data-processed/basin/watershed_HUC4_1202.shp'
# 2023-05-03 13:36:59,090 - root - INFO: ... found 1 shapes
# 2023-05-03 13:36:59,091 - root - INFO: Converting to shapely
# 2023-05-03 13:36:59,097 - root - INFO: Converting to requested CRS
# Drainage area =  24672.363754263846 km^2

# %% [markdown]
# ## import watershed

# %%
# crs, watershed = watershed_workflow.get_split_form_shapes(watershed_shapefile)
# logging.info(f'crs: {crs}')

bounds = watershed.exterior()
bounds

# %% [markdown]
# ## Download Daymet

# %% [markdown]
# returned raw data has `dim(nband, ncol, nrow)`
#
# Note that here we need two files -- the actual data and the typical year data.
#
# The first cell downloads the raw data and generates the actual data file used by ATS, the second cell averages days, smooths the data, and writes a typical year.

# %%
help(watershed_workflow.daymet.daymetToATS)

# %%
# Note: if the data is not being downloded then probably the id had changed and the line [60] on manager_daymet.py must be updated. 
# line [60] --> URL = "https://thredds.daac.ornl.gov/thredds/ncss/ornldaac/2129/daymet_v4_daily_na_{variable}_{year}.nc"

# bounds = watershed.exterior().bounds

# # a dictionary of outputs -- will include all filenames generated
# 2016-2018
# start = "1-2016"
# end = "365-2018"
# outputs = {}
# outputs['daymet_filename'] = f'../../../global_data/rainfall_input_ATS/{name}/{name}_DayMet_2016_2018.h5'

# dat, x, y = watershed_workflow.daymet.collectDaymet(bounds, crs, start, end)

# # Save data into HD5 format
# ats = watershed_workflow.daymet.daymetToATS(dat)
# attrs = watershed_workflow.daymet.getAttrs(bounds, start, end)

# watershed_workflow.daymet.writeHDF5(ats, x, y, attrs, outputs['daymet_filename'])

# %%
# # a dictionary of outputs -- will include all filenames generated
# 2010-2020

# bounds = watershed.exterior().bounds

# start = "1-2010"
# end = "365-2020"
# outputs = {}
# outputs['daymet_filename'] = f'../../../global_data/rainfall_input_ATS/{name}/{name}_DayMet_2010_2020.h5'

# dat, x, y = watershed_workflow.daymet.collectDaymet(bounds, crs, start, end)

# # Save data into HD5 format
# ats = watershed_workflow.daymet.daymetToATS(dat)
# attrs = watershed_workflow.daymet.getAttrs(bounds, start, end)
# watershed_workflow.daymet.writeHDF5(ats, x, y, attrs, outputs['daymet_filename'])

# %%
bounds = watershed.exterior().bounds

# 1980-2020
start = "1-1980"
end = "365-2020"
outputs = {}
32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:57,033 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:57,034 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1992_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:57,377 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:57,378 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1992_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:57,576 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:57,577 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:57,802 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:57,803 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:57,996 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:57,997 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:58,326 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:58,327 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:58,528 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:58,529 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:58,855 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:58,857 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:59,060 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:59,060 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1993_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:59,348 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:59,348 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:59,563 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:59,564 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:37:59,878 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:37:59,879 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:00,238 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:00,239 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:00,443 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:00,444 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:00,731 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:00,732 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:01,119 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:01,120 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1994_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:01,384 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:01,384 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:01,739 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:01,739 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:01,940 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:01,941 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:02,147 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:02,148 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:02,471 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:02,472 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:02,647 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:02,648 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:02,855 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:02,855 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1995_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:03,069 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:03,070 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:03,358 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:03,359 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:03,530 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:03,531 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:03,867 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:03,867 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:04,071 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:04,072 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:04,403 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:04,404 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:04,589 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:04,589 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1996_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:04,866 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:04,867 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:05,052 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:05,052 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:05,369 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:05,370 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:05,637 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:05,638 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:05,906 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:05,907 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:06,114 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:06,115 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:06,454 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:06,455 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1997_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:06,648 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:06,648 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:06,887 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:06,888 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:07,227 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:07,228 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:07,443 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:07,444 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:07,786 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:07,787 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:08,060 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:08,061 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:08,405 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:08,405 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1998_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:08,722 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:08,726 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:08,945 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:08,946 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:09,246 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:09,247 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:09,519 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:09,520 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:09,786 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:09,787 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:10,077 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:10,077 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:10,443 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:10,444 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_1999_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:10,703 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:10,704 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:10,918 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:10,919 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:11,266 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:11,267 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:11,489 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:11,490 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:11,756 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:11,756 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:12,100 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:12,100 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:12,355 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:12,356 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_2000_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:12,546 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:12,547 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:12,855 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:12,856 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:13,213 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:13,214 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:13,561 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:13,562 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:13,905 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:13,906 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:14,168 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:14,169 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:14,432 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:14,433 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_2001_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:14,656 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:14,657 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmin_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:14,983 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:14,984 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_tmax_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:15,283 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:15,283 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_prcp_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:15,599 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:15,600 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_srad_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:15,849 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:15,850 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_vp_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:16,189 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:16,189 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_swe_2002_32.5624x-96.0688_29.9367x-93.6173.nc
# 2023-05-03 13:38:16,389 - root - INFO: Collecting DayMet file to tile bounds: [-96.06880000000001, 29.9367, -93.6173, 32.5624]
# 2023-05-03 13:38:16,389 - root - INFO:   Using existing: /Users/gpq/ORNL/Projects/ATS_runs/global_data/meteorology/daymet/daymet_dayl_2002_32.5624x-96.0688_29.9367x-93.6173.nc

# %% [markdown]
# # White to ATS format

# %%
# Daymet data for spinup

outputs['daymet_spinup_filename'] = f'../../../global_data/rainfall_input_ATS/{name}/{name}_DayMet_typical_1980_2020.h5'
ats_typ = watershed_workflow.daymet.daymetToATS(dat, smooth=True, smooth_filter=True, nyears=40)
watershed_workflow.daymet.writeHDF5(ats_typ, x, y, attrs, outputs['daymet_spinup_filename'])

# %%
# calculate the basin-averaged, annual-averaged precip rate
precip_total = ats_typ['precipitation rain [m s^-1]'] + ats_typ['precipitation snow [m SWE s^-1]']
mean_precip = precip_total.mean()
logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')
